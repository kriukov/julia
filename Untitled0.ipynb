# %%
using PyPlot
# Out:
# Loading help data...

# %%
1+1
# Out:
# 2

# %%
x = linspace(0,2*pi,1000); y = sin(x);

# %%
plot(x, y, color="red", linewidth=2.0)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0xec1c18c>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0xec1c56c>
